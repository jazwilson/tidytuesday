# %% [markdown]
# ### **Eurovision TidyTuesday**
#
# #### @author Dr Jasmine Wilson
# #### @date 23 May 2022
#
# ##### @data [source](https://github.com/rfordatascience/tidytuesday/blob/master/data/2022/2022-05-17/readme.md) The country to country voting data comes from Data.World.

# %%
import pandas as pd
import numpy as np
import os
import plotnine as plt
from plotnine import ggplot, aes, geom_line
from plotnine import *

# %matplotlib inline

# Make the graphs a bit prettier, and bigger
#import matplotlib.pyplot as plt
#plt.style.use('ggplot')
#plt.rcParams['figure.figsize'] = (15, 5)

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

# %%
#Add ?raw=true at the end of the GitHub URL to get the raw file link.
url = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-05-17/eurovision.csv?raw=true'
df = pd.read_csv(url, index_col=0, dtype='unicode')
df
# Out:
#             host_city  year host_country                                event_url           section                     artist                             song                                         artist_url                                          image_url artist_country country_emoji running_order total_points rank rank_ordinal qualified winner
# event
# Turin 2022      Turin  2022        Italy   https://eurovision.tv/event/turin-2022  first-semi-final           Kalush Orchestra                         Stefania  https://eurovision.tv/participant/kalush-orche...  https://static.eurovision.tv/hb-cgi/images/963...        Ukraine     :flag_ua:             6          337    1          1st      TRUE  FALSE
# ...
